# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import random

# Import API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}"


    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()


        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind =  city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | harstad
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | isafjordur
# Processing Record 6 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 1 | vuktyl
# Processing Record 8 of Set 1 | resplendor
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | naracoorte
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | udachny
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | utrik
# Processing Record 16 of Set 1 | ulsteinvik
# Processing Record 17 of Set 1 | grytviken
# Processing Record 18 of Set 1 | gueltat zemmour
# City not found. Skipping...
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | puerto santa
# Processing Record 21 of Set 1 | papatowai
# Processing Record 22 of Set 1 | forster
# Processing Record 23 of Set 1 | shchuchinsk
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | metu
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | belen
# Processing Record 29 of Set 1 | afaahiti
# Processing Record 30 of Set 1 | edinburgh of the seven seas
# Processing Record 31 of Set 1 | severo-yeniseyskiy
# Processing Record 32 of Set 1 | vilyuchinsk
# Processing Record 33 of Set 1 | taman rajawali
# City not found. Skipping...
# Processing Record 34 of Set 1 | whitehorse
# Processing Record 35 of Set 1 | galliano
# Processing Record 36 of Set 1 | codrington
# Processing Record 37 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 1 | bocas del toro
# Processing Record 39 of Set 1 | waitangi
# Processing Record 40 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 1 | toliara
# Processing Record 42 of Set 1 | bilibino
# Processing Record 43 of Set 1 | bayan nur
# City not found. Skipping...
# Processing Record 44 of Set 1 | margaret river
# Processing Record 45 of Set 1 | ca mau
# Processing Record 46 of Set 1 | danilov
# Processing Record 47 of Set 1 | kathmandu
# Processing Record 48 of Set 1 | cockburn town
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | taoudenni
# Processing Record 0 of Set 2 | ouadda
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | trondheim
# Processing Record 3 of Set 2 | saint-pierre
# Processing Record 4 of Set 2 | morogoro
# Processing Record 5 of Set 2 | kayangel
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | buka
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | fale old settlement
# Processing Record 11 of Set 2 | arrifes
# Processing Record 12 of Set 2 | lihue
# Processing Record 13 of Set 2 | 'izbat al burj
# City not found. Skipping...
# Processing Record 14 of Set 2 | pelabuhanratu
# Processing Record 15 of Set 2 | baran
# Processing Record 16 of Set 2 | nevel'sk
# Processing Record 17 of Set 2 | nova sintra
# Processing Record 18 of Set 2 | shingu
# Processing Record 19 of Set 2 | stanley
# Processing Record 20 of Set 2 | pindushi
# Processing Record 21 of Set 2 | keflavik
# Processing Record 22 of Set 2 | fort bragg
# Processing Record 23 of Set 2 | enewetak
# Processing Record 24 of Set 2 | ketchikan
# Processing Record 25 of Set 2 | umba
# Processing Record 26 of Set 2 | polyarnyy
# Processing Record 27 of Set 2 | ebaye
# Processing Record 28 of Set 2 | port mathurin
# Processing Record 29 of Set 2 | troitskoye
# Processing Record 30 of Set 2 | acarau
# Processing Record 31 of Set 2 | san clemente del tuyu
# Processing Record 32 of Set 2 | alaghsas
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | cortez
# Processing Record 35 of Set 2 | constantia
# Processing Record 36 of Set 2 | ra's bayrut
# Processing Record 37 of Set 2 | vorgashor
# Processing Record 38 of Set 2 | lata
# Processing Record 39 of Set 2 | invercargill
# Processing Record 40 of Set 2 | kapa'a
# Processing Record 41 of Set 2 | papao
# Processing Record 42 of Set 2 | crane
# Processing Record 43 of Set 2 | alice springs
# Processing Record 44 of Set 2 | wenchang
# Processing Record 45 of Set 2 | gadzhiyevo
# Processing Record 46 of Set 2 | arbelaez
# Processing Record 47 of Set 2 | fuding
# Processing Record 48 of Set 2 | olonkinbyen
# Processing Record 49 of Set 2 | college
# Processing Record 0 of Set 3 | cidreira
# Processing Record 1 of Set 3 | baoding
# Processing Record 2 of Set 3 | ocos
# Processing Record 3 of Set 3 | newman
# Processing Record 4 of Set 3 | atafu village
# Processing Record 5 of Set 3 | pama
# Processing Record 6 of Set 3 | senj
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | santa elena de uairen
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | west island
# Processing Record 11 of Set 3 | corner brook
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | santa terezinha
# Processing Record 16 of Set 3 | puerto aysen
# Processing Record 17 of Set 3 | bodo
# Processing Record 18 of Set 3 | santiago de cao
# Processing Record 19 of Set 3 | brookings
# Processing Record 20 of Set 3 | ravar
# Processing Record 21 of Set 3 | xining
# Processing Record 22 of Set 3 | arkhangel'sk
# Processing Record 23 of Set 3 | mogocha
# Processing Record 24 of Set 3 | chos malal
# Processing Record 25 of Set 3 | sinop
# Processing Record 26 of Set 3 | kinablangan
# Processing Record 27 of Set 3 | itaituba
# Processing Record 28 of Set 3 | tarawa
# Processing Record 29 of Set 3 | savanna-la-mar
# Processing Record 30 of Set 3 | mokhsogollokh
# Processing Record 31 of Set 3 | hawaiian paradise park
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | okhotsk
# Processing Record 34 of Set 3 | mathba
# Processing Record 35 of Set 3 | ermelo
# Processing Record 36 of Set 3 | xilin hot
# Processing Record 37 of Set 3 | huazhou
# Processing Record 38 of Set 3 | chibougamau
# Processing Record 39 of Set 3 | wailua homesteads
# Processing Record 40 of Set 3 | san luis de la loma
# Processing Record 41 of Set 3 | anadyr
# Processing Record 42 of Set 3 | uturoa
# Processing Record 43 of Set 3 | aripuana
# Processing Record 44 of Set 3 | new plymouth
# Processing Record 45 of Set 3 | kudahuvadhoo
# Processing Record 46 of Set 3 | mossel bay
# Processing Record 47 of Set 3 | san jose de jachal
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | ushuaia
# Processing Record 0 of Set 4 | road town
# Processing Record 1 of Set 4 | kuanda
# Processing Record 2 of Set 4 | trujillo
# Processing Record 3 of Set 4 | udomlya
# Processing Record 4 of Set 4 | labytnangi
# Processing Record 5 of Set 4 | siloam springs
# Processing Record 6 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 7 of Set 4 | winnipeg
# Processing Record 8 of Set 4 | albertina
# Processing Record 9 of Set 4 | cururupu
# Processing Record 10 of Set 4 | san carlos
# Processing Record 11 of Set 4 | point fortin
# Processing Record 12 of Set 4 | sinabang
# Processing Record 13 of Set 4 | markaz-e hukumat-e darweshan
# Processing Record 14 of Set 4 | nadi
# Processing Record 15 of Set 4 | talnakh
# Processing Record 16 of Set 4 | newala kisimani
# Processing Record 17 of Set 4 | gorom-gorom
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | levuka
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | christchurch
# Processing Record 23 of Set 4 | naze
# Processing Record 24 of Set 4 | fisterra
# Processing Record 25 of Set 4 | inirida
# Processing Record 26 of Set 4 | sompeta
# Processing Record 27 of Set 4 | st. john's
# Processing Record 28 of Set 4 | langepas
# Processing Record 29 of Set 4 | labasa
# Processing Record 30 of Set 4 | al ghayzah
# Processing Record 31 of Set 4 | coahuayana de hidalgo
# Processing Record 32 of Set 4 | wotho
# Processing Record 33 of Set 4 | island harbour
# Processing Record 34 of Set 4 | mejit
# Processing Record 35 of Set 4 | nizhneangarsk
# Processing Record 36 of Set 4 | ginir
# Processing Record 37 of Set 4 | aasiaat
# Processing Record 38 of Set 4 | margate
# Processing Record 39 of Set 4 | nemuro
# Processing Record 40 of Set 4 | mocimboa
# Processing Record 41 of Set 4 | albertville
# Processing Record 42 of Set 4 | shangri-la
# City not found. Skipping...
# Processing Record 43 of Set 4 | luena
# Processing Record 44 of Set 4 | bueng kan
# Processing Record 45 of Set 4 | mili
# Processing Record 46 of Set 4 | tidjikja
# Processing Record 47 of Set 4 | nagqu
# Processing Record 48 of Set 4 | kochenevo
# Processing Record 49 of Set 4 | abakaliki
# Processing Record 0 of Set 5 | iskateley
# Processing Record 1 of Set 5 | tsiombe
# Processing Record 2 of Set 5 | sydney
# Processing Record 3 of Set 5 | tomarza
# Processing Record 4 of Set 5 | yuzhno-kurilsk
# Processing Record 5 of Set 5 | itoman
# Processing Record 6 of Set 5 | qaqortoq
# Processing Record 7 of Set 5 | la passe
# Processing Record 8 of Set 5 | ola
# Processing Record 9 of Set 5 | andratx
# Processing Record 10 of Set 5 | sao paulo de olivenca
# Processing Record 11 of Set 5 | mount isa
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | camacupa
# Processing Record 14 of Set 5 | hermanus
# Processing Record 15 of Set 5 | serdar
# Processing Record 16 of Set 5 | kailua-kona
# Processing Record 17 of Set 5 | hamilton
# Processing Record 18 of Set 5 | tharad
# Processing Record 19 of Set 5 | raduzhny
# Processing Record 20 of Set 5 | howard springs
# Processing Record 21 of Set 5 | nadym
# Processing Record 22 of Set 5 | avarua
# Processing Record 23 of Set 5 | ust-nera
# Processing Record 24 of Set 5 | dunay
# Processing Record 25 of Set 5 | jamestown
# Processing Record 26 of Set 5 | selfoss
# Processing Record 27 of Set 5 | igurubi
# Processing Record 28 of Set 5 | fereydunshahr
# Processing Record 29 of Set 5 | sivasli
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | monywa
# Processing Record 32 of Set 5 | meadville
# Processing Record 33 of Set 5 | badger
# Processing Record 34 of Set 5 | hotan
# Processing Record 35 of Set 5 | zheshart
# Processing Record 36 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 37 of Set 5 | valparaiso
# Processing Record 38 of Set 5 | kargopol'
# Processing Record 39 of Set 5 | sadovoye
# Processing Record 40 of Set 5 | el quebrachal
# Processing Record 41 of Set 5 | puerto cabezas
# Processing Record 42 of Set 5 | arkalyk
# Processing Record 43 of Set 5 | necochea
# Processing Record 44 of Set 5 | hadibu
# Processing Record 45 of Set 5 | tura
# Processing Record 46 of Set 5 | rongelap
# Processing Record 47 of Set 5 | bhimunipatnam
# Processing Record 48 of Set 5 | san antonio de pale
# Processing Record 49 of Set 5 | lesnoy
# Processing Record 0 of Set 6 | broome
# Processing Record 1 of Set 6 | miles city
# Processing Record 2 of Set 6 | rio san juan
# Processing Record 3 of Set 6 | kolonia
# Processing Record 4 of Set 6 | pauini
# Processing Record 5 of Set 6 | dahab
# Processing Record 6 of Set 6 | bonthe
# Processing Record 7 of Set 6 | chegdomyn
# Processing Record 8 of Set 6 | piton saint-leu
# Processing Record 9 of Set 6 | gulf shores
# Processing Record 10 of Set 6 | sierra grande
# Processing Record 11 of Set 6 | olyokminsk
# Processing Record 12 of Set 6 | dudinka
# Processing Record 13 of Set 6 | kaga bandoro
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | katsuura
# Processing Record 16 of Set 6 | ulaangom
# Processing Record 17 of Set 6 | howrah
# Processing Record 18 of Set 6 | lala
# Processing Record 19 of Set 6 | yarmouth
# Processing Record 20 of Set 6 | galle
# Processing Record 21 of Set 6 | akureyri
# Processing Record 22 of Set 6 | along
# Processing Record 23 of Set 6 | mahibadhoo
# Processing Record 24 of Set 6 | san pedro pochutla
# Processing Record 25 of Set 6 | lubango
# Processing Record 26 of Set 6 | dakhla
# Processing Record 27 of Set 6 | saldanha
# Processing Record 28 of Set 6 | key largo
# Processing Record 29 of Set 6 | weno
# Processing Record 30 of Set 6 | kisangani
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | new norfolk
# Processing Record 33 of Set 6 | minas de marcona
# Processing Record 34 of Set 6 | harper
# Processing Record 35 of Set 6 | kangavar
# Processing Record 36 of Set 6 | kodiak
# Processing Record 37 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 38 of Set 6 | valdivia
# Processing Record 39 of Set 6 | lazaro cardenas
# Processing Record 40 of Set 6 | montepuez
# Processing Record 41 of Set 6 | lodja
# Processing Record 42 of Set 6 | inhambane
# Processing Record 43 of Set 6 | alotau
# Processing Record 44 of Set 6 | boa vista
# Processing Record 45 of Set 6 | grootfontein
# Processing Record 46 of Set 6 | karamay
# Processing Record 47 of Set 6 | khorixas
# Processing Record 48 of Set 6 | ilulissat
# Processing Record 49 of Set 6 | aitape
# Processing Record 0 of Set 7 | zeya
# Processing Record 1 of Set 7 | changping
# Processing Record 2 of Set 7 | chazuta
# Processing Record 3 of Set 7 | maluso
# Processing Record 4 of Set 7 | cabo san lucas
# Processing Record 5 of Set 7 | komsomol'skiy
# Processing Record 6 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 7 of Set 7 | saudarkrokur
# Processing Record 8 of Set 7 | bac lieu
# Processing Record 9 of Set 7 | saipan
# Processing Record 10 of Set 7 | gadani
# Processing Record 11 of Set 7 | murun-kuren
# Processing Record 12 of Set 7 | salacgriva
# Processing Record 13 of Set 7 | kralendijk
# Processing Record 14 of Set 7 | tshabong
# Processing Record 15 of Set 7 | laayoune plage
# City not found. Skipping...
# Processing Record 16 of Set 7 | pimentel
# Processing Record 17 of Set 7 | mablethorpe
# City not found. Skipping...
# Processing Record 18 of Set 7 | sarandi grande
# Processing Record 19 of Set 7 | salekhard
# Processing Record 20 of Set 7 | beroroha
# Processing Record 21 of Set 7 | coquimbo
# Processing Record 22 of Set 7 | fortuna
# Processing Record 23 of Set 7 | neietsu
# Processing Record 24 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | koluszki
# Processing Record 26 of Set 7 | morden
# Processing Record 27 of Set 7 | laojunmiao
# Processing Record 28 of Set 7 | anna regina
# Processing Record 29 of Set 7 | kievka
# Processing Record 30 of Set 7 | shenkursk
# Processing Record 31 of Set 7 | baglung
# Processing Record 32 of Set 7 | mont-joli
# Processing Record 33 of Set 7 | tejen
# Processing Record 34 of Set 7 | barcelos
# Processing Record 35 of Set 7 | villa la angostura
# Processing Record 36 of Set 7 | praia da vitoria
# Processing Record 37 of Set 7 | kingston
# Processing Record 38 of Set 7 | al marj
# Processing Record 39 of Set 7 | shubarshi
# Processing Record 40 of Set 7 | sechura
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | hiratacho
# Processing Record 43 of Set 7 | plymouth
# Processing Record 44 of Set 7 | mata-utu
# Processing Record 45 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 7 | general villegas
# Processing Record 47 of Set 7 | daru
# Processing Record 48 of Set 7 | luanda
# Processing Record 49 of Set 7 | santa barbara
# Processing Record 0 of Set 8 | klyuchi
# Processing Record 1 of Set 8 | northam
# Processing Record 2 of Set 8 | pacific grove
# Processing Record 3 of Set 8 | awjilah
# Processing Record 4 of Set 8 | flying fish cove
# Processing Record 5 of Set 8 | kununurra
# Processing Record 6 of Set 8 | patnanungan
# Processing Record 7 of Set 8 | pelabuhan klang
# Processing Record 8 of Set 8 | boyolangu
# Processing Record 9 of Set 8 | mezhdurechenskiy
# Processing Record 10 of Set 8 | khilok
# Processing Record 11 of Set 8 | sant'antioco
# Processing Record 12 of Set 8 | nar'yan-mar
# Processing Record 13 of Set 8 | soio
# Processing Record 14 of Set 8 | beira
# Processing Record 15 of Set 8 | conduaga
# Processing Record 16 of Set 8 | rugaji
# Processing Record 17 of Set 8 | paraiso
# Processing Record 18 of Set 8 | cable beach
# City not found. Skipping...
# Processing Record 19 of Set 8 | nikolayevsk-on-amure
# Processing Record 20 of Set 8 | costa rica
# Processing Record 21 of Set 8 | poronaysk
# Processing Record 22 of Set 8 | hithadhoo
# Processing Record 23 of Set 8 | korla
# Processing Record 24 of Set 8 | carepa
# Processing Record 25 of Set 8 | santa fe de antioquia
# Processing Record 26 of Set 8 | caleta de carquin
# Processing Record 27 of Set 8 | crockett
# Processing Record 28 of Set 8 | saratamata
# City not found. Skipping...
# Processing Record 29 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 30 of Set 8 | tadine
# Processing Record 31 of Set 8 | vadso
# Processing Record 32 of Set 8 | bossangoa
# Processing Record 33 of Set 8 | queenstown
# Processing Record 34 of Set 8 | mil'kovo
# Processing Record 35 of Set 8 | ar ruways
# Processing Record 36 of Set 8 | santo augusto
# Processing Record 37 of Set 8 | tazovsky
# Processing Record 38 of Set 8 | colonia
# Processing Record 39 of Set 8 | minzhu
# Processing Record 40 of Set 8 | hilo
# Processing Record 41 of Set 8 | tan-tan
# Processing Record 42 of Set 8 | ouidah
# Processing Record 43 of Set 8 | verkhnevilyuysk
# Processing Record 44 of Set 8 | santa ana de yacuma
# Processing Record 45 of Set 8 | palmer
# Processing Record 46 of Set 8 | mandalgovi
# Processing Record 47 of Set 8 | gurupi
# Processing Record 48 of Set 8 | zaozersk
# Processing Record 49 of Set 8 | barra de santo antonio
# Processing Record 0 of Set 9 | la foa
# Processing Record 1 of Set 9 | sirte
# Processing Record 2 of Set 9 | castelli
# Processing Record 3 of Set 9 | chumphon
# Processing Record 4 of Set 9 | aydarken
# Processing Record 5 of Set 9 | kavaratti
# Processing Record 6 of Set 9 | san julian
# Processing Record 7 of Set 9 | las heras
# Processing Record 8 of Set 9 | sept-iles
# Processing Record 9 of Set 9 | tralee
# Processing Record 10 of Set 9 | virginia
# Processing Record 11 of Set 9 | rio grande
# Processing Record 12 of Set 9 | mogadishu
# Processing Record 13 of Set 9 | holualoa
# Processing Record 14 of Set 9 | pisco
# Processing Record 15 of Set 9 | puerto el triunfo
# Processing Record 16 of Set 9 | kamen'-rybolov
# Processing Record 17 of Set 9 | lensk
# Processing Record 18 of Set 9 | leh
# Processing Record 19 of Set 9 | ust'-ilimsk
# Processing Record 20 of Set 9 | bakchar
# Processing Record 21 of Set 9 | lagos
# Processing Record 22 of Set 9 | bentiu
# Processing Record 23 of Set 9 | melo
# Processing Record 24 of Set 9 | lamu
# Processing Record 25 of Set 9 | beloyarskiy
# Processing Record 26 of Set 9 | kangding
# Processing Record 27 of Set 9 | karasburg
# Processing Record 28 of Set 9 | turaif
# Processing Record 29 of Set 9 | egilsstadir
# Processing Record 30 of Set 9 | wainwright
# Processing Record 31 of Set 9 | charleston
# Processing Record 32 of Set 9 | sorong
# Processing Record 33 of Set 9 | ta`u
# Processing Record 34 of Set 9 | sitka
# Processing Record 35 of Set 9 | vila franca do campo
# Processing Record 36 of Set 9 | morfelden-walldorf
# Processing Record 37 of Set 9 | ambon
# Processing Record 38 of Set 9 | spas-demensk
# Processing Record 39 of Set 9 | el granada
# Processing Record 40 of Set 9 | haiku-pauwela
# Processing Record 41 of Set 9 | meulaboh
# Processing Record 42 of Set 9 | telaga batu
# City not found. Skipping...
# Processing Record 43 of Set 9 | kollam
# Processing Record 44 of Set 9 | decorah
# Processing Record 45 of Set 9 | molde
# Processing Record 46 of Set 9 | plouzane
# Processing Record 47 of Set 9 | xam nua
# Processing Record 48 of Set 9 | chulakkurgan
# Processing Record 49 of Set 9 | viedma
# Processing Record 0 of Set 10 | baikonur
# Processing Record 1 of Set 10 | elliot lake
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | kone
# Processing Record 4 of Set 10 | umatac village
# City not found. Skipping...
# Processing Record 5 of Set 10 | hualien city
# Processing Record 6 of Set 10 | santo antonio
# Processing Record 7 of Set 10 | sisimiut
# Processing Record 8 of Set 10 | dunedin
# Processing Record 9 of Set 10 | peno
# Processing Record 10 of Set 10 | umm kaddadah
# Processing Record 11 of Set 10 | east honolulu
# City not found. Skipping...
# Processing Record 12 of Set 10 | tindouf
# Processing Record 13 of Set 10 | phalaborwa
# Processing Record 14 of Set 10 | nandyal
# Processing Record 15 of Set 10 | hirara
# Processing Record 16 of Set 10 | carnarvon
# Processing Record 17 of Set 10 | brisas de zicatela
# Processing Record 18 of Set 10 | vikulovo
# Processing Record 19 of Set 10 | burang
# Processing Record 20 of Set 10 | zhezqazghan
# Processing Record 21 of Set 10 | konstantinovka
# Processing Record 22 of Set 10 | arraial do cabo
# Processing Record 23 of Set 10 | sandpoint
# Processing Record 24 of Set 10 | okmulgee
# Processing Record 25 of Set 10 | minas de matahambre
# Processing Record 26 of Set 10 | causeni
# Processing Record 27 of Set 10 | south hedland
# Processing Record 28 of Set 10 | gaoual
# Processing Record 29 of Set 10 | sa'dah
# Processing Record 30 of Set 10 | olmaliq
# Processing Record 31 of Set 10 | york beach
# Processing Record 32 of Set 10 | remire-montjoly
# Processing Record 33 of Set 10 | tonekabon
# Processing Record 34 of Set 10 | vershino-darasunskiy
# Processing Record 35 of Set 10 | torit
# Processing Record 36 of Set 10 | greenville
# Processing Record 37 of Set 10 | fort st. john
# Processing Record 38 of Set 10 | choele choel
# Processing Record 39 of Set 10 | novoagansk
# Processing Record 40 of Set 10 | mozarlandia
# Processing Record 41 of Set 10 | klaksvik
# Processing Record 42 of Set 10 | kintinku
# Processing Record 43 of Set 10 | ceeldheer
# Processing Record 44 of Set 10 | kencong
# Processing Record 45 of Set 10 | port saint john's
# Processing Record 46 of Set 10 | batroun
# Processing Record 47 of Set 10 | el calafate
# Processing Record 48 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 10 | muang phonsavan
# Processing Record 0 of Set 11 | aljezur
# Processing Record 1 of Set 11 | diego de almagro
# Processing Record 2 of Set 11 | balancan
# Processing Record 3 of Set 11 | chonchi
# Processing Record 4 of Set 11 | kismayo
# Processing Record 5 of Set 11 | jwaneng
# Processing Record 6 of Set 11 | port orange
# Processing Record 7 of Set 11 | pyapon
# Processing Record 8 of Set 11 | beyneu
# Processing Record 9 of Set 11 | suva
# Processing Record 10 of Set 11 | agua prieta
# Processing Record 11 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 12 of Set 11 | yeosu
# Processing Record 13 of Set 11 | kaspiyskiy
# Processing Record 14 of Set 11 | laascaanood
# Processing Record 15 of Set 11 | patterson
# Processing Record 16 of Set 11 | san juan
# Processing Record 17 of Set 11 | ad dawadimi
# Processing Record 18 of Set 11 | okha
# Processing Record 19 of Set 11 | usinsk
# Processing Record 20 of Set 11 | tabuk
# Processing Record 21 of Set 11 | armidale
# Processing Record 22 of Set 11 | middelburg
# Processing Record 23 of Set 11 | red lion
# Processing Record 24 of Set 11 | gamba
# Processing Record 25 of Set 11 | tolanaro
# Processing Record 26 of Set 11 | vila velha
# Processing Record 27 of Set 11 | neelankarai
# Processing Record 28 of Set 11 | santiago papasquiaro
# Processing Record 29 of Set 11 | tamanrasset
# Processing Record 30 of Set 11 | chui
# Processing Record 31 of Set 11 | mgandu
# Processing Record 32 of Set 11 | al kharj
# Processing Record 33 of Set 11 | hammerfest
# Processing Record 34 of Set 11 | takab
# Processing Record 35 of Set 11 | ponta delgada
# Processing Record 36 of Set 11 | lebyazh'ye
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | kristiansund
# Processing Record 39 of Set 11 | n'zeto
# Processing Record 40 of Set 11 | walvis bay
# Processing Record 41 of Set 11 | ilomantsi
# Processing Record 42 of Set 11 | quellon
# Processing Record 43 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 44 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 45 of Set 11 | guerrero negro
# Processing Record 46 of Set 11 | bereznik
# Processing Record 47 of Set 11 | mirabad
# Processing Record 48 of Set 11 | dalby
# Processing Record 49 of Set 11 | kotido
# Processing Record 0 of Set 12 | tanki leendert
# City not found. Skipping...
# Processing Record 1 of Set 12 | shalkar
# Processing Record 2 of Set 12 | kalisz
# Processing Record 3 of Set 12 | saint-martin-des-champs
# Processing Record 4 of Set 12 | fort mcmurray
# Processing Record 5 of Set 12 | manay
# Processing Record 6 of Set 12 | abu 'arish
# City not found. Skipping...
# Processing Record 7 of Set 12 | kapuskasing
# Processing Record 8 of Set 12 | kuusamo
# Processing Record 9 of Set 12 | ak'ordat
# Processing Record 10 of Set 12 | portales
# Processing Record 11 of Set 12 | woolgoolga
# Processing Record 12 of Set 12 | nellore
# Processing Record 13 of Set 12 | nicoya
# Processing Record 14 of Set 12 | arica
# Processing Record 15 of Set 12 | borrazopolis
# Processing Record 16 of Set 12 | inhuma
# Processing Record 17 of Set 12 | rancharia
# Processing Record 18 of Set 12 | kualakapuas
# Processing Record 19 of Set 12 | baltasi
# Processing Record 20 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 12 | happy valley-goose bay
# Processing Record 22 of Set 12 | miyaly
# Processing Record 23 of Set 12 | la pesa
# Processing Record 24 of Set 12 | susuman
# Processing Record 25 of Set 12 | cannonvale
# Processing Record 26 of Set 12 | mukachevo
# Processing Record 27 of Set 12 | bartica
# Processing Record 28 of Set 12 | shengli
# Processing Record 29 of Set 12 | baranovichi
# Processing Record 30 of Set 12 | rustenburg
# Processing Record 31 of Set 12 | kerikeri
# Processing Record 32 of Set 12 | berezovyy
# Processing Record 33 of Set 12 | mount pearl
# Processing Record 34 of Set 12 | san patricio
# Processing Record 35 of Set 12 | ouani
# Processing Record 36 of Set 12 | carauari
# Processing Record 37 of Set 12 | jinshi
# Processing Record 38 of Set 12 | lompoc
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167    279.52        91          97
# 1            harstad  68.7990   16.5293    268.38        77          44
# 2     puerto natales -51.7236  -72.4875    287.40        44          40
# 3          adamstown -25.0660 -130.1015    298.42        83         100
# 4         isafjordur  66.0755  -23.1240    271.59        84          99
#
#    Wind Speed Country        Date
# 0       14.00      TF  1739552964
# 1        4.47      NO  1739553199
# 2        9.26      CL  1739553200
# 3        9.85      PN  1739553201
# 4        3.74      IS  1739553202

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    279.52        91          97
# 1                  harstad  68.7990   16.5293    268.38        77          44
# 2           puerto natales -51.7236  -72.4875    287.40        44          40
# 3                adamstown -25.0660 -130.1015    298.42        83         100
# 4               isafjordur  66.0755  -23.1240    271.59        84          99
#
#          Wind Speed Country        Date
# City_ID
# 0             14.00      TF  1739552964
# 1              4.47      NO  1739553199
# 2              9.26      CL  1739553200
# 3              9.85      PN  1739553201
# 4              3.74      IS  1739553202

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (°F)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (mph)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, save_path):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           harstad  68.7990   16.5293    268.38        77          44
# 4        isafjordur  66.0755  -23.1240    271.59        84          99
# 5            vuktyl  63.8567   57.3094    249.28       100          50
# 7            albany  42.6001  -73.9662    270.56        59          68
# 10            tiksi  71.6872  128.8694    243.62       100          94
#
#          Wind Speed Country        Date
# City_ID
# 1              4.47      NO  1739553199
# 4              3.74      IS  1739553202
# 5              1.49      RU  1739553004
# 7              2.24      US  1739553160
# 10             0.88      RU  1739553210

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167    279.52        91          97
# 2           puerto natales -51.7236  -72.4875    287.40        44          40
# 3                adamstown -25.0660 -130.1015    298.42        83         100
# 6               resplendor -19.3256  -41.2553    307.54        39          12
# 8               naracoorte -36.9579  140.7383    287.00        62         100
#
#          Wind Speed Country        Date
# City_ID
# 0             14.00      TF  1739552964
# 2              9.26      CL  1739553200
# 3              9.85      PN  1739553201
# 6              1.91      BR  1739553206
# 8              5.12      AU  1739553208

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Northern hemisphere

northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
 
# Linear Regression for Northern Hemisphere
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df["Lat"], 
                                                        northern_hemi_df["Max Temp"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
 
plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.plot(northern_hemi_df["Lat"], regress_values, "r-")
plt.annotate(line_eq, (45, 0), fontsize=15, color="red")
plt.title(f"Northern Hemisphere: Temperature vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.savefig("output_data/north_regression.png")
plt.show()

# %%
# Southern hemisphere

southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Linear Regression for Southern Hemisphere
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df["Lat"],
                                                        southern_hemi_df["Max Temp"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
 
plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.plot(southern_hemi_df["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-45, 0), fontsize=15, color="red")
plt.title(f"Southern Hemisphere: Temperature vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.savefig("output_data/south_regression.png")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Linear Regression for Northern Hemisphere Humidity vs. Latitude
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df["Lat"], 
                                                        northern_hemi_df["Humidity"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], label='Data Points')
plt.plot(northern_hemi_df["Lat"], regress_values, "r-", label='Linear Regression Line')
plt.annotate(line_eq, (45, min(regress_values) + 5), fontsize=15, color="red")
plt.title(f"Northern Hemisphere: Humidity vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.legend()
plt.savefig("output_data/north_humidity_lat_regression.png")
plt.show()

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Linear Regression for Southern Hemisphere Humidity vs. Latitude
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df["Lat"], 
                                                        southern_hemi_df["Humidity"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], label='Data Points')
plt.plot(southern_hemi_df["Lat"], regress_values, "r-", label='Linear Regression Line')
plt.annotate(line_eq, (min(southern_hemi_df["Lat"]) + 5, min(regress_values) + 5), fontsize=15, color="red")
plt.title(f"Southern Hemisphere: Humidity vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.legend()
plt.savefig("output_data/south_humidity_lat_regression.png")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Linear Regression for Northern Hemisphere Cloudiness vs. Latitude
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df["Lat"], 
                                                        northern_hemi_df["Cloudiness"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], label='Data Points')
plt.plot(northern_hemi_df["Lat"], regress_values, "r-", label='Linear Regression Line')
plt.annotate(line_eq, (min(northern_hemi_df["Lat"]) + 5, min(regress_values) + 5), fontsize=15, color="red")
plt.title(f"Northern Hemisphere: Cloudiness vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.legend()
plt.savefig("output_data/north_cloudiness_lat_regression.png")
plt.show()

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Linear Regression for Southern Hemisphere Cloudiness vs. Latitude
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df["Lat"], 
                                                        southern_hemi_df["Cloudiness"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], label='Data Points')
plt.plot(southern_hemi_df["Lat"], regress_values, "r-", label='Linear Regression Line')
plt.annotate(line_eq, (min(southern_hemi_df["Lat"]) + 5, min(regress_values) + 5), fontsize=15, color="red")
plt.title(f"Southern Hemisphere: Cloudiness vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.legend()
plt.savefig("output_data/south_cloudiness_lat_regression.png")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
#
# # Northern Hemisphere
# In this graph, the r^2 value is very close to zero, indicating a weak relationship and showing that the independent variable (i.e. latitude) may not
# be relevant in explaining or predicting cloudiness in the Northern Hemisphere. This weak relationship could explain several phenomena such as poor data
# quality, incorrect data entries or missing valaues.
#
# # Southern Hemisphere
# In this graph, the r^2-value is 0.018616831531634456, again indicating a very weak relationship between latitude and cloudiness which is the
# dependent variable. This weak relationship does not provide a statistically sufficient explanation of the relationship between latitude and
# cloudiness in the Southern Hemisphere. To show a strong relationship and hence provide a statistically strong linear relationship between these two
#     variables - latitude and cloudiness - as shown in this graph, the data must be assessed and cleaned up for all errors and inaccuracies.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Filter for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Linear Regression for Northern Hemisphere Wind Speed vs. Latitude
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df["Lat"], 
                                                        northern_hemi_df["Wind Speed"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.figure(figsize=(10, 6))
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], label='Data Points')
plt.plot(northern_hemi_df["Lat"], regress_values, "r-", label='Linear Regression Line')
plt.annotate(line_eq, (min(northern_hemi_df["Lat"]) + 5, min(regress_values) + 1), fontsize=15, color="red")
plt.title(f"Northern Hemisphere: Wind Speed vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.legend()
plt.savefig("output_data/north_wind_speed_lat_regression.png")
plt.show()

# %%
# Southern Hemisphere
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Linear Regression for Southern Hemisphere Wind Speed vs. Latitude
slope, intercept, r_value, p_value, std_err = linregress(southern_hemi_df["Lat"], 
                                                        southern_hemi_df["Wind Speed"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.figure(figsize=(10, 6))
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], label='Data Points')
plt.plot(southern_hemi_df["Lat"], regress_values, "r-", label='Linear Regression Line')
plt.annotate(line_eq, (min(southern_hemi_df["Lat"]) + 5, min(regress_values) + 1), fontsize=15, color="red")
plt.title(f"Southern Hemisphere: Wind Speed vs. Latitude (r={r_value:.2f})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.legend()
plt.savefig("output_data/south_wind_speed_lat_regression.png")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:**
#
# # Northern Hemisphere
# Here, the r^2-value is 0.0017236249523139959, which is very low and shows a weak relationship between latitude and windspeed. With this model,
# this relationship is just too weak and irrelevant for predicting a statistically sound relationship between the independent and dependent variables,
# which in this case are the latitude and windspeed.
#
# # Southern Hemisphere
# Here, again, the relationship between latitude and windspeed is weak. This graph or linear relationship is not strong enough to give a statistically
# convincing explation of how latitude, the independent variable, influence wind speed which the independent variable. However, it should be noted that
# r^2-value is 0.06495869418886388, while showing a weak relationship, is statistically more significant than the values in the previous graphs
# showing linear relationship between the independent and dependent variables.

# %%
In summary, all the graphs plotted above show a linear relationship between the variables. However the relationship is so weak and cannot be used
to provide any statistically sound explanation between the independent and dependent variable.
# Out:
#   Cell In[40], line 1
#     In summary, all the graphs plotted above show a linear relationship between the variables. However the relationship is so weak and cannot be used
#        ^
# SyntaxError: invalid syntax
